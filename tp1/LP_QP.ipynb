# %% [markdown]
# <center><img src="Fig/Ensimag.png" width="30%" height="30%"></center>
# <center><h3>ENSIMAG  -- 2A</h3></center>
# <hr>
# <center><h1>Optimisation Numérique</h1></center>
# <center><h2>TP : Linear and Quadratic programs (1.5h)</h2></center>

# %% [markdown]
# # Structure of an optimization program
#
# An optimization program can be practically divided into three parts:
# * the *run* environment, in which you test, run your program, and display results.
# * the *problem* part, which contains the function oracles, problem constraints, etc.
# * the *algorithmic* part, where the algorithms are coded.
#
# The main interest of such division is that these parts are interchangeable, meaning that, for instance, the algorithms of the third part can be used of a variety of problems. That is why such a decomposition is widely used.
#
# In the present lab, you will use this division:
# * `LP_and_QP_problems.ipynb` will be the *run* environment
# * `toy_problem.ipynb` will be the considered the *problem* for this lab
# * the library `cvxopt` will be used for solving all optimization problems
#
# ---
#
# The following script will allow you to import *notebooks* as if you imported *python files* and will have to be executed at each time you launch Jupyter notebooks.

# %%
import start
from importlib import reload

# %% [markdown]
# ---
#
# # Regression model
#
#
# We consider the regression model
#
# $$ y=X\theta+\xi,\;\;\xi\sim \mathcal{N}(0, \sigma I_m), $$
#
# where $X\in \mathbb{R}^{m\times n}$ and $y\in \mathbb{R}^m$ are the observed values and $\theta\in \mathbb{R}^n$ is the unknown parameter we want to find.
#
# We want to find a value $\widehat{\theta}$ such that
# - the quadratic error $e(\widehat{\theta}) = 1/2 \|X\widehat{\theta} - y \|_2^2$ is (near)-minimal, that is $ \| \nabla e(\widehat{\theta}) \| = \| X^\mathrm{T} (X\widehat{\theta} - y) \| $ is small.

# %% [markdown]
# ---
#
# # the Dantzig Selector
#
#
# The **Dantzig Selector** for $\theta$, introduced in *Emmanuel Candes and Terrence Tao "The Dantzig selector: Statistical estimation when $p$ is much larger than $n$". The Annals of Statistics, 2007* can be used to estimate $\theta$ in the case of an overparametrized problem, i.e. when the dimension $n$ of $\theta$ is well greater than the dimension of the observation $y$.
#
#
#
#
# In that case, the estimator $\widehat{\theta}_{DS}$ is the solution of the optimization problem
# $$
# \widehat{\theta}_{DS} \in \arg\min_{\theta\in \mathbb{R}^n} \left\{\|\theta\|_1,\;\mbox{with}\;\|X^T(X\theta-y)\|_\infty\leq \kappa\sigma\right\},
# $$
# where $\kappa>0$ is an *hyper-parameter*.
#
#
# The best theoretical value for $\kappa$ is $\nu q_{\mathcal{N}} \left(1-\frac{\alpha}{2n}\right)$, where  $\alpha\in(0,1)$ is the chosen risk level (e.g. $\alpha=.05$), $q_\mathcal{N}(p)$ is the $p$-quantile of the standard normal distribution, and $\nu=\max_j\|[X]_j\|_2$ is the maximal column norm of matrix $X$.
#
#
# **Objective:** Implement a function that return the Dantzig estimator $\widehat{\theta}_{DS}$ from input $(y,X,\sigma)$ using linear programming solver `cvxopt`.

# %% [markdown]
# > Reformulate the $\arg\min$ problem as a linear program.
#
#
# > Write a function `DantzigSelector` that takes `y,X,sigma` as an input and outputs $\widehat{\theta}_{DS}$ by using the linear program solver of the library `cvxopt` <a href="http://cvxopt.org/userguide/coneprog.html#linear-programming">lp</a> which, given $c, G, h$ solves the problem
# $$ \min_x c^\mathrm{T}x ~~~~~~ \text{ subject to } Gx \leq h $$
# where the inequality is elementwise.
#
# *Hint: Useful functions are* `np.concatenate` `np.zeros` `np.eye` `np.hstack` `np.vstack`

# %%
from cvxopt import matrix, solvers

from scipy.stats import norm
import numpy as np

def DantzigSelector(y,X,sigma):
    
    # Extracting the sizes
    m,n = X.shape
    
    # Computing kappa
    alpha = 0.05
    nu = max(np.linalg.norm(X, axis=0))
    kappa = nu*norm.ppf(1-alpha/(2.0*n))
    #PRECOMPUTE
    XtX = X.T @ X
    Xty = X.T @ y
    #PARAMS
    
    c = np.concatenate([np.ones(n), np.zeros(n),np.zeros(n)])
    I = np.eye(n)
    Z = np.zeros((n,n))
    
    #CONTRAINTS(7n)
    
    #1\theta <= u  → theta+ - theta- - u ≤ 0
    G1 = np.hstack([-I,I,-I])
    h1 = np.zeros(n)
    #2\-theta <= u → -theta+ + theta- - u ≤ 0
    G2 = np.hstack([-I, -I, I])
    h2 = np.zeros(n)
    #3\u >= 0
    G3 = np.hstack([-I, Z, Z])
    h3 = np.zeros(n)
    #4\theta+ >= 0
    G4 = np.hstack([Z, -I, Z])
    h4 = np.zeros(n)    
    #5\theta- >= 0
    G5 = np.hstack([Z, Z, -I])
    h5 = np.zeros(n)
    #6\Dantzig thetha +
    G6 = np.hstack([Z,XtX,-XtX])
    h6 = kappa*sigma + Xty
    #7\Dantzig thetha -
    G7 = np.hstack([Z,-XtX,XtX])
    h7 = kappa*sigma - Xty
    
    #REGROUPING 
    G = np.vstack([G1, G2, G3, G4, G5, G6, G7])
    h = np.concatenate([h1, h2, h3, h4, h5, h6, h7])
    #####################################################
    # Prepare c, G, h
    assert c.shape == (3*n,)
    assert G.shape == (7*n, 3*n)
    assert h.shape == (7*n,)
    
    c_cvx = matrix(c)
    G_cvx = matrix(G)
    h_cvx = matrix(h)
    
    sol = solvers.conelp(c_cvx, G_cvx, h_cvx)
    x_cvx = sol['x']
    x = np.array(sol['x']).flatten()
    assert x.shape == (3*n,)
    
    # Recover theta
    theta_plus = x[n:2*n]
    theta_minus = x[2*n:3*n]
    theta = theta_plus - theta_minus
    assert theta.shape == (n,)
    
    return theta

# %% [markdown]
# > Test your code on the toy problem given in `toy_problem.ipynb`. For this randomly generated problem, there is a true $\theta$ upon which the problem is built.

# %%
import toy_problemm as tPb
from importlib import reload
reload(tPb)


theta_ds = DantzigSelector(tPb.y,tPb.X,tPb.sigma)
# Out:
#      pcost       dcost       gap    pres   dres   k/t
#  0:  0.0000e+00 -2.1191e+02  3e+03  4e+00  3e+00  1e+00
#  1:  5.1586e+00 -4.5111e+01  4e+02  1e+00  8e-01  4e+00
#  2:  3.9136e+00 -1.3656e+01  1e+02  4e-01  3e-01  2e+00
#  3:  4.2049e+00 -3.7336e+00  4e+01  2e-01  1e-01  9e-01
#  4:  4.3805e+00  1.4120e+00  1e+01  7e-02  5e-02  2e-01
#  5:  4.6049e+00  4.2923e+00  1e+00  6e-03  5e-03  5e-03
#  6:  4.6305e+00  4.6000e+00  1e-01  6e-04  5e-04  5e-04
#  7:  4.6331e+00  4.6328e+00  1e-03  6e-06  5e-06  5e-06
#  8:  4.6331e+00  4.6331e+00  1e-05  6e-08  5e-08  5e-08
#  9:  4.6331e+00  4.6331e+00  1e-07  6e-10  5e-10  5e-10
# Optimal solution found.

# %% [markdown]
# > Investigate the differences between the Dantzig selector and the Ground truth

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.plot(tPb.theta,'ro',label='ground truth')
plt.plot(theta_ds,'b*',label='Dantzig selector')
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# # the Lasso
#
# Under the same regression model, the Least Absolute Shrinkage and Selection Operator or **lasso** for $\theta$, introduced in *Robert Tibshirani "Regression shrinkage and selection via the lasso", Journal of the Royal Statistical Society, 1996* can also be used to estimate $\theta$.
#
# The estimator $\widehat{\theta}_{L}$ is the solution of the optimization problem
# $$
# \widehat{\theta}_{L} \in \arg\min_{\theta\in \mathbb{R}^n} \left\{ \|X\theta - y\|_2^2 + \kappa \sigma \|\theta\|_1 \right\},
# $$
# where $\kappa>0$ is an *hyper-parameter*.
#
#
# The best theoretical value for $\kappa$ is the same as for the Dantzig selector: $\nu q_{\mathcal{N}} \left(1-\frac{\alpha}{2n}\right)$, where  $\alpha\in(0,1)$ is the chosen risk level (e.g. $\alpha=.05$), $q_\mathcal{N}(p)$ is the $p$-quantile of the standard normal distribution, and $\nu=\max_j\|[X]_j\|_2$ is the maximal column norm of matrix $X$.
#
#
# **Objective:** Implement a function that return the lasso estimator $\widehat{\theta}_{L}$ from input $(y,X,\sigma)$ using quadratic programming solver `cvxopt`.

# %% [markdown]
# > Reformulate the $\arg\min$ problem as a quadratic program.
#
#
# > Write a function `Lasso` that takes `y,X,sigma` as an input and outputs $\widehat{\theta}_{L}$ by using the quadratic program solver of the library `cvxopt` <a href="http://cvxopt.org/userguide/coneprog.html#quadratic-programming">qp</a> which, given $P,q, G, h$ solves the problem
# $$ \min_x 1/2 x^\mathrm{T} P x + q^\mathrm{T}x ~~~~~~ \text{ subject to } Gx \leq h $$
# where the inequality is elementwise.
#
# *Hint: Useful functions are* `np.concatenate` `np.zeros` `np.eye` `np.hstack` `np.vstack`

# %%
from cvxopt import matrix, solvers

from scipy.stats import norm
import numpy as np

def Lasso(y,X,sigma):
    
    # Extracting the sizes
    m,n = X.shape
    
    # Computing kappa
    alpha = 0.05
    nu = max(np.linalg.norm(X, axis=0))
    kappa = nu*norm.ppf(1-alpha/(2.0*n))
    #PRECOMPUTE
    XtX = X.T @ X
    Xty = X.T @ y
    #PARAMS
    I = np.eye(n)
    I2n = np.eye(2*n)
    Z = np.zeros(2*n)
    # COMPUTE AND SOLVE QP PROBLEM
    #theta conditions
    G1 = -I2n
    G2 =np.hstack([-I,-I])
    G = np.vstack([G1, G2])
    h = np.concatenate([Z, np.zeros(n)])
    #Q condition
    q = np.concatenate([
        -2*Xty + kappa*sigma*np.ones(n),
        2*Xty + kappa*sigma*np.ones(n)
    ])
    #P condition
    P = 2 * np.block([
        [XtX, -XtX],
        [-XtX, XtX]
    ])
    # Prepare P, q, G, h
    # assert P.shape == (2*n, 2*n)
    # assert q.shape == (2*n,)
    # assert G.shape == (3*n, 2*n)
    # assert h.shape == (3*n,)
    P_cvx = matrix(P)
    q_cvx = matrix(q)
    G_cvx = matrix(G)
    h_cvx = matrix(h)
    
    sol = solvers.qp(P_cvx, q_cvx, G_cvx, h_cvx)
    x_cvx = sol['x']
    x = np.squeeze(np.array(x_cvx))
    assert x.shape == (2*n,)
    
    # Recover theta
    theta = x[:n] - x[n:]
    assert theta.shape == (n,)
    
    return theta

# %% [markdown]
# > Test your code on the toy problem given in `toy_problem.ipynb`. For this randomly generated problem, there is a true $\theta$ upon which the problem is built.

# %%
import toy_problemm as tPb
from importlib import reload
reload(tPb)


theta_l = Lasso(tPb.y,tPb.X,tPb.sigma)
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -3.3554e+01  1.3904e+02  1e+03  4e+01  3e+00
#  1:  1.1204e+02 -3.9079e+00  1e+02  5e-15  3e-15
#  2:  1.2366e+01 -3.4640e+00  2e+01  3e-15  2e-15
#  3:  3.5996e+00 -2.6889e+00  6e+00  1e-15  1e-15
#  4: -7.8966e-01 -2.3793e+00  2e+00  4e-16  8e-16
#  5: -1.9932e+00 -2.2670e+00  3e-01  3e-16  8e-16
#  6: -2.2147e+00 -2.2478e+00  3e-02  4e-16  9e-16
#  7: -2.2449e+00 -2.2458e+00  9e-04  4e-16  9e-16
#  8: -2.2456e+00 -2.2457e+00  3e-05  2e-16  1e-15
#  9: -2.2457e+00 -2.2457e+00  1e-06  3e-16  9e-16
# Optimal solution found.

# %% [markdown]
# > Investigate the differences between the Lasso and the Ground truth

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.plot(tPb.theta,'ro',label='ground truth')
plt.plot(theta_l,'k*',label='Lasso')
plt.legend()
plt.show()

# %% [markdown]
# # Comparing and Improving
#
#
# > Compute the lasso and Dantzig selector solutions for the same problem and investigate their compared performance graphically and by computing the error on the null and non-null coordinates of theta.
#
#
# > Play with the values of $n,m,\sigma, S$ to exhibit differences in behaviors.

# %%
import toy_problemm as tPb
from importlib import reload
reload(tPb)



theta_l = Lasso(tPb.y,tPb.X,tPb.sigma)
theta_ds = DantzigSelector(tPb.y,tPb.X,tPb.sigma)
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -3.6781e+01  1.5502e+02  1e+03  4e+01  3e+00
#  1:  1.2904e+02 -6.7266e+00  1e+02  7e-15  3e-15
#  2:  1.1071e+01 -5.9681e+00  2e+01  3e-15  3e-15
#  3:  9.6048e-01 -5.1293e+00  6e+00  1e-15  1e-15
#  4: -3.7595e+00 -4.8731e+00  1e+00  6e-16  1e-15
#  5: -4.5861e+00 -4.7720e+00  2e-01  7e-16  1e-15
#  6: -4.7407e+00 -4.7552e+00  1e-02  6e-16  1e-15
#  7: -4.7533e+00 -4.7540e+00  7e-04  5e-16  1e-15
#  8: -4.7540e+00 -4.7540e+00  1e-05  7e-16  1e-15
#  9: -4.7540e+00 -4.7540e+00  1e-07  4e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres   k/t
#  0:  0.0000e+00 -2.1191e+02  3e+03  5e+00  3e+00  1e+00
#  1:  3.1060e+00 -5.0788e+01  4e+02  1e+00  9e-01  4e+00
#  2:  1.8602e+00 -1.7500e+01  1e+02  5e-01  3e-01  3e+00
#  3:  2.7193e+00 -6.6587e+00  5e+01  3e-01  2e-01  1e+00
#  4:  3.0740e+00 -2.3578e+00  3e+01  1e-01  9e-02  6e-01
#  5:  3.3415e+00  2.2502e+00  4e+00  3e-02  2e-02  2e-02
#  6:  3.4883e+00  3.3773e+00  4e-01  3e-03  2e-03  2e-03
#  7:  3.5035e+00  3.5021e+00  5e-03  3e-05  2e-05  2e-05
#  8:  3.5037e+00  3.5036e+00  5e-05  3e-07  2e-07  2e-07
#  9:  3.5037e+00  3.5037e+00  5e-07  3e-09  2e-09  2e-09
# Optimal solution found.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.plot(tPb.theta,'ro',label='ground truth')
plt.plot(theta_ds,'b*',label='Dantzig selector')
plt.plot(theta_l,'k*',label='Lasso')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline



plt.figure()
plt.plot(tPb.theta[tPb.non_null],'ro',label='ground truth')
plt.plot(theta_ds[tPb.non_null],'b*',label='Dantzig selector')
plt.plot(theta_l[tPb.non_null],'k*',label='Lasso')
plt.legend()
plt.show()

err_theta_DS = np.linalg.norm(theta_ds[tPb.non_null] -tPb.theta[tPb.non_null]  , ord=1)
err_theta_L = np.linalg.norm(theta_l[tPb.non_null]-tPb.theta[tPb.non_null] , ord=1)

print("Error on the non-null coefficients\n Dantzig selec. \t Lasso")
print(err_theta_DS,err_theta_L)
# Out:
# Error on the non-null coefficients
#  Dantzig selec. 	 Lasso
# 2.318461361217824 1.4946039284987893

# %%
err_supp_DS = 0
err_supp_L = 0
for i in range(tPb.n):
    if i not in  tPb.non_null:
        err_supp_DS += np.abs(theta_ds[i])
        err_supp_L += np.abs(theta_l[i])

print("Error on the null coefficients\n Dantzig selec. \t Lasso")
print(float(err_supp_DS),float(err_supp_L))
# Out:
# Error on the null coefficients
#  Dantzig selec. 	 Lasso
# 4.3772117097606866e-08 0.4017579042214527

# %%
print("Error on y \n Dantzig selec. \t Lasso")
print(float(np.linalg.norm(np.dot(tPb.X, theta_ds ) - tPb.y )),float(np.linalg.norm(np.dot(tPb.X, theta_l ) - tPb.y )))
# Out:
# Error on y
#  Dantzig selec. 	 Lasso
# 1.281592786076478 0.9181974149505322

# %%
print("Quadratic error \n Dantzig selec. \t Lasso")
print(float(np.linalg.norm(np.dot(tPb.X.T , np.dot(tPb.X, theta_ds ) - tPb.y ))),float(np.linalg.norm(np.dot(tPb.X.T , np.dot(tPb.X, theta_l ) - tPb.y ))))
# Out:
# Quadratic error
#  Dantzig selec. 	 Lasso
# 2.498834133365502 1.6896146169247312

# %% [markdown]
# # To go further
#
#
# ### Improved Estimators
#
# A popular improvement of these estimators is to weigh the threshold $\kappa$ with the norm corresponding column of $X$.
#
# The improved Dantzig and Lasso estimators $\widehat{\theta'}_{DS}$ and $\widehat{\theta'}_{L}$  are thus solutions of
# $$
# \widehat{\theta}_{DS} \in \arg\min_{\theta\in \mathbb{R}^n} \left\{\|\theta\|_1,\;\mbox{with}\;| [ X^T(X\theta-y)]_i  | \leq \kappa_i \sigma ~~ \forall i\right\},
# $$
# and
# $$
# \widehat{\theta}_{L} \in \arg\min_{\theta\in \mathbb{R}^n} \left\{ \|X\theta - y\|_2^2 + \sum_{i=1}^n \kappa_i \sigma |\theta_i | \right\},
# $$
# where $\kappa_i = \| X_i \|_2 \kappa = \| X_i \|_2 q_{\mathcal{N}} \left(1-\frac{\alpha}{2n}\right) $ where $\| X_i \|_2$ is the $2$-norm of the $i$-th column of $X$.
#
#
#
# > Investigate the pertinence of this improvement. (Get rid of the normalization in the problem).

# %%
from cvxopt import matrix, solvers
from scipy.stats import norm
import numpy as np

def DantzigSelectorImproved(y, X, sigma):
    
    m, n = X.shape
    
    # ----- kappa -----
    alpha = 0.05
    nu = 1   # as indicated in your TP
    kappa = nu * norm.ppf(1 - alpha/(2.0*n))
    
    # ----- kappa vector -----
    kappa_vec = np.linalg.norm(X, axis=0) * kappa  # (n,)
    
    # Precompute
    XtX = X.T @ X
    Xty = X.T @ y
    
    # =====================================================
    # VARIABLE x = [theta+ ; theta-]
    # =====================================================
    
    # Objective
    c = np.concatenate([np.ones(n), np.ones(n)])
    
    # =====================================================
    # CONSTRAINTS
    # =====================================================
    
    I = np.eye(n)
    
    # Dantzig +
    G1 = np.hstack([XtX, -XtX])
    h1 = kappa_vec * sigma + Xty
    
    # Dantzig -
    G2 = np.hstack([-XtX, XtX])
    h2 = kappa_vec * sigma - Xty
    
    # positivity
    G3 = -np.eye(2*n)
    h3 = np.zeros(2*n)
    
    # stack
    G = np.vstack([G1, G2, G3])
    h = np.concatenate([h1, h2, h3])
    
    # =====================================================
    # Solve LP
    # =====================================================
    
    c_cvx = matrix(c)
    G_cvx = matrix(G)
    h_cvx = matrix(h)
    
    sol = solvers.lp(c_cvx, G_cvx, h_cvx)
    x = np.array(sol['x']).flatten()
    
    # Recover theta
    theta = x[:n] - x[n:]
    
    return theta

# %%
from cvxopt import matrix, solvers
from scipy.stats import norm
import numpy as np

def LassoImproved(y, X, sigma):
    
    m, n = X.shape
    
    # ----- kappa -----
    alpha = 0.05
    nu = 1
    kappa = nu * norm.ppf(1 - alpha/(2.0*n))
    
    # ----- kappa vector -----
    kappa_vec = np.linalg.norm(X, axis=0) * kappa  # (n,)
    
    # Precompute
    XtX = X.T @ X
    Xty = X.T @ y
    
    # =====================================================
    # VARIABLE x = [theta+ ; theta-]
    # =====================================================
    
    # ----- P -----
    P = 2 * np.block([
        [XtX, -XtX],
        [-XtX, XtX]
    ])
    
    # ----- q (IMPORTANT CHANGE HERE) -----
    q = np.concatenate([
        -2*Xty + sigma * kappa_vec,
         2*Xty + sigma * kappa_vec
    ])
    
    # ----- Constraints -----
    G1 = -np.eye(2*n)
    h1 = np.zeros(2*n)
    
    # extra block (for 3n constraint format)
    G2 = np.hstack([-np.eye(n), -np.eye(n)])
    h2 = np.zeros(n)
    
    G = np.vstack([G1, G2])
    h = np.concatenate([h1, h2])
    
    # =====================================================
    # Solve QP
    # =====================================================
    
    P_cvx = matrix(P)
    q_cvx = matrix(q)
    G_cvx = matrix(G)
    h_cvx = matrix(h)
    
    sol = solvers.qp(P_cvx, q_cvx, G_cvx, h_cvx)
    x = np.array(sol['x']).flatten()
    
    # Recover theta
    theta = x[:n] - x[n:]
    
    return theta

# %%
import toy_problemm as tPb
from importlib import reload
reload(tPb)

theta_l = Lasso(tPb.y,tPb.X,tPb.sigma)
theta_ds = DantzigSelector(tPb.y,tPb.X,tPb.sigma)
theta_li = LassoImproved(tPb.y,tPb.X,tPb.sigma)
theta_dsi = DantzigSelectorImproved(tPb.y,tPb.X,tPb.sigma)
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -4.0979e+01  1.5536e+02  1e+03  4e+01  2e+00
#  1:  1.2944e+02 -1.0647e+01  1e+02  7e-15  3e-15
#  2:  1.7117e+01 -9.7209e+00  3e+01  3e-15  2e-15
#  3:  3.0629e+00 -8.8292e+00  1e+01  1e-15  1e-15
#  4: -3.6085e+00 -8.4344e+00  5e+00  8e-16  9e-16
#  5: -6.8375e+00 -8.2311e+00  1e+00  4e-16  9e-16
#  6: -7.9902e+00 -8.1444e+00  2e-01  6e-16  1e-15
#  7: -8.1268e+00 -8.1347e+00  8e-03  4e-16  1e-15
#  8: -8.1340e+00 -8.1342e+00  2e-04  8e-16  1e-15
#  9: -8.1342e+00 -8.1342e+00  5e-06  7e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres   k/t
#  0:  0.0000e+00 -2.1191e+02  3e+03  5e+00  3e+00  1e+00
#  1:  4.9267e+00 -5.2600e+01  5e+02  1e+00  1e+00  4e+00
#  2:  3.7632e+00 -1.9467e+01  1e+02  6e-01  4e-01  3e+00
#  3:  4.4284e+00 -6.6809e+00  6e+01  3e-01  2e-01  1e+00
#  4:  4.6729e+00 -1.1485e+00  3e+01  1e-01  1e-01  6e-01
#  5:  4.9299e+00  1.3008e+00  2e+01  9e-02  6e-02  3e-01
#  6:  5.1303e+00  4.0510e+00  5e+00  2e-02  2e-02  5e-02
#  7:  5.2306e+00  4.7893e+00  2e+00  1e-02  7e-03  2e-02
#  8:  5.2837e+00  5.2519e+00  1e-01  7e-04  5e-04  9e-04
#  9:  5.2881e+00  5.2877e+00  2e-03  9e-06  6e-06  1e-05
# 10:  5.2881e+00  5.2881e+00  2e-05  9e-08  6e-08  1e-07
# 11:  5.2881e+00  5.2881e+00  2e-07  9e-10  6e-10  1e-09
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -4.0979e+01  1.5536e+02  1e+03  4e+01  2e+00
#  1:  1.2944e+02 -1.0647e+01  1e+02  6e-15  3e-15
#  2:  1.7117e+01 -9.7209e+00  3e+01  3e-15  2e-15
#  3:  3.0629e+00 -8.8292e+00  1e+01  1e-15  1e-15
#  4: -3.6085e+00 -8.4344e+00  5e+00  7e-16  1e-15
#  5: -6.8375e+00 -8.2311e+00  1e+00  8e-16  1e-15
#  6: -7.9902e+00 -8.1444e+00  2e-01  1e-15  1e-15
#  7: -8.1268e+00 -8.1347e+00  8e-03  8e-16  1e-15
#  8: -8.1340e+00 -8.1342e+00  2e-04  1e-15  1e-15
#  9: -8.1342e+00 -8.1342e+00  5e-06  8e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres   k/t
#  0: -3.9690e-15 -2.1191e+02  2e+03  3e+00  1e+00  1e+00
#  1: -1.0263e+01 -3.0608e+01  1e+02  3e-01  1e-01  1e+00
#  2: -2.6517e+00 -1.3295e+01  5e+01  2e-01  5e-02  5e-01
#  3: -1.5490e-01 -7.1317e+00  3e+01  1e-01  3e-02  3e-01
#  4:  2.2734e+00 -1.3740e+00  2e+01  5e-02  2e-02  1e-01
#  5:  3.8070e+00  2.2810e+00  7e+00  2e-02  7e-03  2e-02
#  6:  4.5714e+00  3.8426e+00  3e+00  1e-02  3e-03  9e-03
#  7:  5.2142e+00  5.1428e+00  3e-01  1e-03  3e-04  6e-04
#  8:  5.2859e+00  5.2837e+00  9e-03  3e-05  1e-05  2e-05
#  9:  5.2881e+00  5.2881e+00  9e-05  3e-07  1e-07  2e-07
# 10:  5.2881e+00  5.2881e+00  9e-07  3e-09  1e-09  2e-09
# Optimal solution found.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.plot(tPb.theta,'ro',label='ground truth')
plt.plot(theta_ds,'b*',label='Dantzig selector')
plt.plot(theta_l,'k*',label='Lasso')
plt.plot(theta_dsi,'g*',label='Improved Dantzig selector')
plt.plot(theta_li,'y*',label='Improved Lasso')
plt.legend()
plt.show()

# %%
err_theta_DS = np.linalg.norm(theta_ds[tPb.non_null] -tPb.theta[tPb.non_null]  , ord=1)
err_theta_L = np.linalg.norm(theta_l[tPb.non_null]-tPb.theta[tPb.non_null] , ord=1)
err_theta_DSI = np.linalg.norm(theta_dsi[tPb.non_null] -tPb.theta[tPb.non_null]  , ord=1)
err_theta_LI = np.linalg.norm(theta_li[tPb.non_null]-tPb.theta[tPb.non_null] , ord=1)

print("Error on the non-null coefficients")
print(err_theta_DS,err_theta_L, err_theta_DSI, err_theta_LI)
# Out:
# Error on the non-null coefficients
# 3.0478110356249006 2.000090617077024 3.047811093796944 2.0000906170770225

# %% [markdown]
# ### Crossed Validation of the thresholds
#
# The values of $\kappa$ is heavily linked to the noise standard deviation $\sigma$ and theoretical considerations about $X$ and $\theta$. A practical way to choose $\kappa$ without the knowledge of $\sigma$ is to use *cross-validation*.
#
# - Split y and X in two parts column-wise, one part for *training* and one for *testing*.
# - For several values of $\kappa$, solve the estimation problem *on the training part* using $\kappa$ to get a estimate $\widehat{\theta}_\kappa$.
# - For each $\widehat{\theta}_\kappa$, compute the error *on the testing part* $e(\kappa) = \| y_{test}-X_{test}\widehat{\theta}_\kappa \|$.
# - Choose the value that minimize this error $\widehat{\kappa} = \arg \min_{\kappa} e(\kappa)$.
#
#
# > Implement a cross validation procedure to choose $\kappa$. Compare the value and the outputted estimate with the theoretic value.

# %%
import numpy as np
from cvxopt import matrix, solvers
from scipy.stats import norm
import matplotlib.pyplot as plt

# =====================================================
# LASSO with fixed kappa
# =====================================================
def Lasso_fixed_kappa(y, X, sigma, kappa):
    
    m, n = X.shape
    
    XtX = X.T @ X
    Xty = X.T @ y
    
    # P
    P = 2 * np.block([
        [XtX, -XtX],
        [-XtX, XtX]
    ])
    
    # q
    q = np.concatenate([
        -2*Xty + kappa*sigma*np.ones(n),
        2*Xty + kappa*sigma*np.ones(n)
    ])
    
    # Constraints
    G1 = -np.eye(2*n)
    h1 = np.zeros(2*n)
    
    G2 = np.hstack([-np.eye(n), -np.eye(n)])
    h2 = np.zeros(n)
    
    G = np.vstack([G1, G2])
    h = np.concatenate([h1, h2])
    
    # Solve QP
    sol = solvers.qp(matrix(P), matrix(q), matrix(G), matrix(h))
    x = np.array(sol['x']).flatten()
    
    theta = x[:n] - x[n:]
    
    return theta


# =====================================================
# TRAIN / TEST SPLIT
# =====================================================
def train_test_split(X, y, ratio=0.7):
    m = X.shape[0]
    idx = np.random.permutation(m)
    
    split = int(ratio * m)
    
    train_idx = idx[:split]
    test_idx = idx[split:]
    
    return X[train_idx], y[train_idx], X[test_idx], y[test_idx]


# =====================================================
# CROSS VALIDATION
# =====================================================
def cross_validate_lasso(X, y, sigma, kappa_list):
    
    X_train, y_train, X_test, y_test = train_test_split(X, y)
    
    errors = []
    thetas = []
    
    for kappa in kappa_list:
        
        theta = Lasso_fixed_kappa(y_train, X_train, sigma, kappa)
        
        err = np.linalg.norm(X_test @ theta - y_test)
        
        errors.append(err)
        thetas.append(theta)
    
    best_idx = np.argmin(errors)
    
    return kappa_list[best_idx], thetas[best_idx], errors


# =====================================================
# MAIN TEST
# =====================================================

# Data 
import toy_problemm as tPb

X = tPb.X
y = tPb.y
sigma = tPb.sigma

m, n = X.shape

# ---- Theoretical kappa ----
alpha = 0.05
nu = 1
kappa_theory = nu * norm.ppf(1 - alpha/(2*n))

# ---- Candidate kappas ----
kappa_list = np.logspace(-2, 1, 20)

# ---- Cross-validation ----
kappa_cv, theta_cv, errors = cross_validate_lasso(X, y, sigma, kappa_list)

# ---- Compute theoretical solution ----
theta_theory = Lasso_fixed_kappa(y, X, sigma, kappa_theory)

# =====================================================
# RESULTS
# =====================================================

print("Theoretical kappa:", kappa_theory)
print("Cross-validated kappa:", kappa_cv)

print("\nError comparison:")
print("Theory error:", np.linalg.norm(X @ theta_theory - y))
print("CV error:", np.linalg.norm(X @ theta_cv - y))


# =====================================================
# PLOT
# =====================================================
plt.figure()
plt.plot(kappa_list, errors, marker='o')
plt.xscale('log')
plt.xlabel("kappa")
plt.ylabel("Test error")
plt.title("Cross-validation curve")
plt.grid()
plt.show()
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -7.9675e+00 -6.5553e+00  1e+03  3e+01  3e+00
#  1: -7.5139e+00 -6.5255e+01  6e+01  2e+00  2e-01
#  2: -7.4909e+00 -8.3113e+00  8e-01  9e-03  9e-04
#  3: -7.9228e+00 -8.0014e+00  8e-02  5e-15  4e-15
#  4: -7.9629e+00 -7.9978e+00  3e-02  2e-15  2e-15
#  5: -7.9771e+00 -7.9963e+00  2e-02  1e-15  1e-15
#  6: -7.9888e+00 -7.9952e+00  6e-03  7e-16  8e-16
#  7: -7.9924e+00 -7.9946e+00  2e-03  1e-15  8e-16
#  8: -7.9934e+00 -7.9944e+00  1e-03  6e-16  8e-16
#  9: -7.9939e+00 -7.9943e+00  4e-04  5e-16  8e-16
# 10: -7.9941e+00 -7.9943e+00  2e-04  1e-15  8e-16
# 11: -7.9942e+00 -7.9943e+00  5e-05  9e-16  9e-16
# 12: -7.9943e+00 -7.9943e+00  2e-05  7e-16  9e-16
# 13: -7.9943e+00 -7.9943e+00  5e-06  8e-16  9e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -7.9677e+00 -6.3545e+00  1e+03  3e+01  3e+00
#  1: -7.2997e+00 -6.5123e+01  6e+01  2e+00  2e-01
#  2: -7.2707e+00 -8.1736e+00  9e-01  5e-03  5e-04
#  3: -7.9196e+00 -8.0002e+00  8e-02  4e-04  4e-05
#  4: -7.9525e+00 -7.9940e+00  4e-02  2e-04  2e-05
#  5: -7.9694e+00 -7.9919e+00  2e-02  6e-05  5e-06
#  6: -7.9840e+00 -7.9901e+00  6e-03  1e-05  1e-06
#  7: -7.9876e+00 -7.9893e+00  2e-03  2e-06  2e-07
#  8: -7.9883e+00 -7.9892e+00  9e-04  1e-06  1e-07
#  9: -7.9888e+00 -7.9891e+00  3e-04  3e-07  3e-08
# 10: -7.9890e+00 -7.9891e+00  1e-04  9e-08  9e-09
# 11: -7.9890e+00 -7.9891e+00  5e-05  3e-08  3e-09
# 12: -7.9891e+00 -7.9891e+00  2e-05  6e-09  6e-10
# 13: -7.9891e+00 -7.9891e+00  3e-06  1e-09  1e-10
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -7.9682e+00 -6.0657e+00  1e+03  3e+01  3e+00
#  1: -6.9919e+00 -6.4934e+01  6e+01  2e+00  2e-01
#  2: -6.9600e+00 -7.9987e+00  1e+00  6e-15  4e-15
#  3: -7.8963e+00 -7.9949e+00  1e-01  4e-15  3e-15
#  4: -7.9359e+00 -7.9874e+00  5e-02  2e-15  2e-15
#  5: -7.9599e+00 -7.9852e+00  3e-02  1e-15  1e-15
#  6: -7.9758e+00 -7.9828e+00  7e-03  8e-16  9e-16
#  7: -7.9797e+00 -7.9820e+00  2e-03  8e-16  9e-16
#  8: -7.9809e+00 -7.9818e+00  9e-04  7e-16  8e-16
#  9: -7.9813e+00 -7.9817e+00  4e-04  8e-16  8e-16
# 10: -7.9815e+00 -7.9817e+00  1e-04  8e-16  1e-15
# 11: -7.9816e+00 -7.9816e+00  5e-05  5e-16  9e-16
# 12: -7.9816e+00 -7.9816e+00  1e-05  6e-16  9e-16
# 13: -7.9816e+00 -7.9816e+00  2e-06  1e-15  9e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -7.9691e+00 -5.6504e+00  1e+03  3e+01  3e+00
#  1: -6.5498e+00 -6.4662e+01  6e+01  2e+00  2e-01
#  2: -6.5256e+00 -7.9955e+00  1e+00  6e-15  4e-15
#  3: -7.8502e+00 -7.9899e+00  1e-01  3e-15  3e-15
#  4: -7.9061e+00 -7.9791e+00  7e-02  2e-15  2e-15
#  5: -7.9409e+00 -7.9760e+00  4e-02  9e-16  9e-16
#  6: -7.9630e+00 -7.9725e+00  9e-03  9e-16  9e-16
#  7: -7.9681e+00 -7.9714e+00  3e-03  7e-16  8e-16
#  8: -7.9700e+00 -7.9711e+00  1e-03  6e-16  9e-16
#  9: -7.9705e+00 -7.9710e+00  5e-04  6e-16  1e-15
# 10: -7.9708e+00 -7.9710e+00  2e-04  8e-16  9e-16
# 11: -7.9709e+00 -7.9710e+00  7e-05  9e-16  9e-16
# 12: -7.9709e+00 -7.9709e+00  2e-05  9e-16  9e-16
# 13: -7.9709e+00 -7.9709e+00  2e-06  8e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -7.9711e+00 -5.0534e+00  1e+03  3e+01  3e+00
#  1: -5.9151e+00 -6.4272e+01  6e+01  2e+00  2e-01
#  2: -5.9256e+00 -7.9907e+00  2e+00  6e-15  4e-15
#  3: -7.7856e+00 -7.9826e+00  2e-01  4e-15  3e-15
#  4: -7.8643e+00 -7.9671e+00  1e-01  2e-15  2e-15
#  5: -7.9152e+00 -7.9627e+00  5e-02  9e-16  9e-16
#  6: -7.9453e+00 -7.9576e+00  1e-02  6e-16  9e-16
#  7: -7.9515e+00 -7.9563e+00  5e-03  1e-15  8e-16
#  8: -7.9543e+00 -7.9559e+00  2e-03  1e-15  1e-15
#  9: -7.9550e+00 -7.9557e+00  7e-04  5e-16  8e-16
# 10: -7.9554e+00 -7.9556e+00  2e-04  5e-16  8e-16
# 11: -7.9555e+00 -7.9556e+00  9e-05  5e-16  8e-16
# 12: -7.9556e+00 -7.9556e+00  2e-05  9e-16  9e-16
# 13: -7.9556e+00 -7.9556e+00  2e-06  9e-16  9e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -7.9752e+00 -4.1956e+00  1e+03  3e+01  3e+00
#  1: -5.0047e+00 -6.3713e+01  6e+01  2e+00  2e-01
#  2: -5.1122e+00 -7.9839e+00  3e+00  6e-15  4e-15
#  3: -7.6963e+00 -7.9719e+00  3e-01  4e-15  3e-15
#  4: -7.8062e+00 -7.9495e+00  1e-01  2e-15  2e-15
#  5: -7.8795e+00 -7.9436e+00  6e-02  9e-16  9e-16
#  6: -7.9189e+00 -7.9364e+00  2e-02  7e-16  9e-16
#  7: -7.9276e+00 -7.9346e+00  7e-03  6e-16  1e-15
#  8: -7.9318e+00 -7.9340e+00  2e-03  2e-15  1e-15
#  9: -7.9329e+00 -7.9337e+00  9e-04  8e-16  9e-16
# 10: -7.9334e+00 -7.9336e+00  3e-04  9e-16  1e-15
# 11: -7.9335e+00 -7.9336e+00  9e-05  6e-16  7e-16
# 12: -7.9335e+00 -7.9336e+00  3e-05  6e-16  8e-16
# 13: -7.9336e+00 -7.9336e+00  1e-06  9e-16  9e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -7.9838e+00 -2.9634e+00  1e+03  3e+01  3e+00
#  1: -3.7005e+00 -6.2910e+01  6e+01  2e+00  2e-01
#  2: -4.0389e+00 -7.9740e+00  4e+00  6e-15  4e-15
#  3: -7.5747e+00 -7.9560e+00  4e-01  3e-15  3e-15
#  4: -7.7268e+00 -7.9239e+00  2e-01  1e-15  1e-15
#  5: -7.8228e+00 -7.9166e+00  9e-02  1e-15  9e-16
#  6: -7.8817e+00 -7.9060e+00  2e-02  1e-15  9e-16
#  7: -7.8939e+00 -7.9034e+00  1e-02  7e-16  9e-16
#  8: -7.8995e+00 -7.9026e+00  3e-03  6e-16  9e-16
#  9: -7.9013e+00 -7.9022e+00  9e-04  6e-16  9e-16
# 10: -7.9018e+00 -7.9021e+00  2e-04  1e-15  1e-15
# 11: -7.9020e+00 -7.9020e+00  2e-05  5e-16  1e-15
# 12: -7.9020e+00 -7.9020e+00  2e-06  1e-15  9e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -8.0015e+00 -1.1946e+00  1e+03  3e+01  3e+00
#  1: -1.8355e+00 -6.1763e+01  6e+01  2e+00  2e-01
#  2: -2.6800e+00 -7.9596e+00  5e+00  5e-15  3e-15
#  3: -7.2541e+00 -7.9332e+00  7e-01  3e-15  2e-15
#  4: -7.5514e+00 -7.8904e+00  3e-01  1e-15  1e-15
#  5: -7.7072e+00 -7.8780e+00  2e-01  9e-16  9e-16
#  6: -7.8163e+00 -7.8640e+00  5e-02  6e-16  8e-16
#  7: -7.8457e+00 -7.8586e+00  1e-02  7e-16  9e-16
#  8: -7.8519e+00 -7.8578e+00  6e-03  1e-15  8e-16
#  9: -7.8554e+00 -7.8572e+00  2e-03  6e-16  9e-16
# 10: -7.8564e+00 -7.8570e+00  7e-04  6e-16  8e-16
# 11: -7.8568e+00 -7.8570e+00  2e-04  6e-16  9e-16
# 12: -7.8569e+00 -7.8570e+00  2e-05  6e-16  1e-15
# 13: -7.8569e+00 -7.8570e+00  2e-06  8e-16  9e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -8.0380e+00  1.3424e+00  1e+03  3e+01  3e+00
#  1:  8.2437e-01 -6.0124e+01  7e+01  2e+00  2e-01
#  2: -1.0653e+00 -7.9385e+00  7e+00  5e-15  3e-15
#  3: -6.6053e+00 -7.9004e+00  1e+00  3e-15  2e-15
#  4: -7.2579e+00 -7.8444e+00  6e-01  1e-15  1e-15
#  5: -7.5160e+00 -7.8237e+00  3e-01  1e-15  9e-16
#  6: -7.7143e+00 -7.8052e+00  9e-02  6e-16  8e-16
#  7: -7.7671e+00 -7.7964e+00  3e-02  8e-16  9e-16
#  8: -7.7813e+00 -7.7940e+00  1e-02  1e-15  8e-16
#  9: -7.7887e+00 -7.7932e+00  5e-03  9e-16  9e-16
# 10: -7.7918e+00 -7.7928e+00  1e-03  8e-16  1e-15
# 11: -7.7926e+00 -7.7927e+00  5e-05  1e-15  1e-15
# 12: -7.7927e+00 -7.7927e+00  5e-06  9e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -8.1137e+00  4.9764e+00  1e+03  3e+01  3e+00
#  1:  4.6037e+00 -5.7793e+01  7e+01  2e+00  2e-01
#  2:  6.6448e-01 -7.9074e+00  9e+00  6e-15  3e-15
#  3: -5.6213e+00 -7.8521e+00  2e+00  3e-15  2e-15
#  4: -6.8684e+00 -7.7769e+00  9e-01  1e-15  1e-15
#  5: -7.2762e+00 -7.7450e+00  5e-01  7e-16  8e-16
#  6: -7.5735e+00 -7.7206e+00  1e-01  5e-16  9e-16
#  7: -7.6605e+00 -7.7071e+00  5e-02  6e-16  8e-16
#  8: -7.6848e+00 -7.7032e+00  2e-02  7e-16  9e-16
#  9: -7.6969e+00 -7.7021e+00  5e-03  1e-15  9e-16
# 10: -7.7004e+00 -7.7014e+00  1e-03  7e-16  8e-16
# 11: -7.7012e+00 -7.7013e+00  1e-04  7e-16  1e-15
# 12: -7.7013e+00 -7.7013e+00  1e-06  7e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -8.2703e+00  1.0172e+01  1e+03  3e+01  3e+00
#  1:  9.9444e+00 -5.4492e+01  7e+01  2e+00  2e-01
#  2:  2.1895e+00 -7.8613e+00  1e+01  5e-15  3e-15
#  3: -4.3718e+00 -7.7795e+00  3e+00  3e-15  2e-15
#  4: -6.3533e+00 -7.6775e+00  1e+00  1e-15  1e-15
#  5: -6.9614e+00 -7.6320e+00  7e-01  8e-16  8e-16
#  6: -7.3878e+00 -7.5989e+00  2e-01  6e-16  9e-16
#  7: -7.5175e+00 -7.5796e+00  6e-02  1e-15  1e-15
#  8: -7.5516e+00 -7.5744e+00  2e-02  9e-16  8e-16
#  9: -7.5663e+00 -7.5732e+00  7e-03  6e-16  1e-15
# 10: -7.5715e+00 -7.5722e+00  8e-04  6e-16  9e-16
# 11: -7.5721e+00 -7.5721e+00  7e-05  1e-15  1e-15
# 12: -7.5721e+00 -7.5721e+00  1e-06  9e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -8.5944e+00  1.7579e+01  1e+03  3e+01  3e+00
#  1:  1.7432e+01 -4.9852e+01  7e+01  1e+00  1e-01
#  2:  2.9605e+00 -7.7915e+00  1e+01  5e-15  3e-15
#  3: -3.2774e+00 -7.6648e+00  4e+00  2e-15  2e-15
#  4: -5.6982e+00 -7.5274e+00  2e+00  1e-15  1e-15
#  5: -6.5670e+00 -7.4694e+00  9e-01  7e-16  8e-16
#  6: -7.1528e+00 -7.4237e+00  3e-01  1e-15  9e-16
#  7: -7.3250e+00 -7.3994e+00  7e-02  1e-15  8e-16
#  8: -7.3687e+00 -7.3933e+00  2e-02  7e-16  9e-16
#  9: -7.3842e+00 -7.3920e+00  8e-03  6e-16  9e-16
# 10: -7.3899e+00 -7.3911e+00  1e-03  8e-16  1e-15
# 11: -7.3909e+00 -7.3910e+00  3e-05  7e-16  1e-15
# 12: -7.3909e+00 -7.3909e+00  5e-07  9e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -9.2648e+00  2.8099e+01  1e+03  3e+01  3e+00
#  1:  2.7809e+01 -4.3394e+01  8e+01  1e+00  1e-01
#  2:  2.2363e+00 -7.6835e+00  1e+01  4e-15  3e-15
#  3: -3.3268e+00 -7.4557e+00  4e+00  2e-15  1e-15
#  4: -5.3135e+00 -7.2839e+00  2e+00  9e-16  9e-16
#  5: -6.4900e+00 -7.2260e+00  7e-01  1e-15  9e-16
#  6: -6.9449e+00 -7.1664e+00  2e-01  8e-16  9e-16
#  7: -7.0842e+00 -7.1462e+00  6e-02  9e-16  9e-16
#  8: -7.1218e+00 -7.1412e+00  2e-02  1e-15  9e-16
#  9: -7.1357e+00 -7.1398e+00  4e-03  1e-15  9e-16
# 10: -7.1390e+00 -7.1394e+00  4e-04  7e-16  1e-15
# 11: -7.1393e+00 -7.1394e+00  6e-06  7e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -1.0652e+01  4.2948e+01  1e+03  3e+01  3e+00
#  1:  4.1951e+01 -3.4538e+01  8e+01  1e+00  9e-02
#  2: -5.7137e-01 -7.5140e+00  7e+00  3e-15  3e-15
#  3: -3.7460e+00 -7.1164e+00  3e+00  1e-15  1e-15
#  4: -5.1331e+00 -6.9625e+00  2e+00  1e-15  9e-16
#  5: -6.3301e+00 -6.8568e+00  5e-01  8e-16  9e-16
#  6: -6.6734e+00 -6.8090e+00  1e-01  7e-16  9e-16
#  7: -6.7645e+00 -6.7975e+00  3e-02  1e-15  9e-16
#  8: -6.7913e+00 -6.7948e+00  3e-03  2e-15  1e-15
#  9: -6.7941e+00 -6.7944e+00  4e-04  7e-16  1e-15
# 10: -6.7944e+00 -6.7944e+00  5e-06  7e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -1.3523e+01  6.3725e+01  1e+03  4e+01  3e+00
#  1:  6.0751e+01 -2.2651e+01  9e+01  6e-01  5e-02
#  2:  1.5521e+00 -7.4763e+00  9e+00  6e-02  5e-03
#  3: -2.4739e+00 -6.7733e+00  4e+00  2e-02  2e-03
#  4: -4.2238e+00 -6.5430e+00  2e+00  7e-03  6e-04
#  5: -5.7774e+00 -6.3977e+00  6e-01  8e-04  7e-05
#  6: -6.1761e+00 -6.3456e+00  2e-01  2e-04  2e-05
#  7: -6.3018e+00 -6.3311e+00  3e-02  3e-05  2e-06
#  8: -6.3267e+00 -6.3285e+00  2e-03  6e-07  5e-08
#  9: -6.3283e+00 -6.3284e+00  7e-05  2e-08  2e-09
# 10: -6.3283e+00 -6.3283e+00  2e-06  3e-10  3e-11
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -1.9462e+01  9.2404e+01  1e+03  4e+01  3e+00
#  1:  8.4826e+01 -7.4098e+00  9e+01  6e-15  3e-15
#  2:  4.0537e+00 -6.9077e+00  1e+01  3e-15  2e-15
#  3: -7.0921e-01 -6.2024e+00  5e+00  1e-15  1e-15
#  4: -3.0806e+00 -5.9508e+00  3e+00  7e-16  9e-16
#  5: -5.0896e+00 -5.7800e+00  7e-01  6e-16  1e-15
#  6: -5.5646e+00 -5.7267e+00  2e-01  5e-16  1e-15
#  7: -5.6897e+00 -5.7144e+00  2e-02  6e-16  9e-16
#  8: -5.7113e+00 -5.7126e+00  1e-03  5e-16  8e-16
#  9: -5.7125e+00 -5.7125e+00  3e-05  7e-16  1e-15
# 10: -5.7125e+00 -5.7125e+00  3e-07  7e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -3.1752e+01  1.3116e+02  1e+03  4e+01  3e+00
#  1:  1.1031e+02 -7.2611e+00  1e+02  6e-15  2e-15
#  2:  9.7286e+00 -6.5522e+00  2e+01  3e-15  2e-15
#  3:  1.6376e+00 -5.5172e+00  7e+00  1e-15  1e-15
#  4: -1.2288e+00 -5.2010e+00  4e+00  4e-16  8e-16
#  5: -4.0117e+00 -4.9964e+00  1e+00  6e-16  9e-16
#  6: -4.7965e+00 -4.9302e+00  1e-01  5e-16  1e-15
#  7: -4.9035e+00 -4.9213e+00  2e-02  1e-15  1e-15
#  8: -4.9196e+00 -4.9202e+00  7e-04  8e-16  1e-15
#  9: -4.9202e+00 -4.9202e+00  2e-05  5e-16  1e-15
# 10: -4.9202e+00 -4.9202e+00  6e-07  4e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -5.7181e+01  1.8174e+02  1e+03  4e+01  2e+00
#  1:  1.3410e+02 -7.0572e+00  1e+02  6e-15  2e-15
#  2:  1.5919e+01 -6.0198e+00  2e+01  2e-15  2e-15
#  3:  3.6292e+00 -4.5598e+00  8e+00  8e-16  9e-16
#  4:  6.8070e-01 -4.2377e+00  5e+00  6e-16  9e-16
#  5: -2.3608e+00 -4.0222e+00  2e+00  7e-16  9e-16
#  6: -3.7090e+00 -3.9430e+00  2e-01  7e-16  1e-15
#  7: -3.9255e+00 -3.9328e+00  7e-03  8e-16  1e-15
#  8: -3.9323e+00 -3.9324e+00  1e-04  9e-16  1e-15
#  9: -3.9324e+00 -3.9324e+00  5e-06  2e-16  1e-15
# 10: -3.9324e+00 -3.9324e+00  4e-07  7e-16  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -1.0980e+02 -7.0136e+00  3e+02  4e+01  1e-15
#  1: -2.0346e+01 -6.6851e+00  4e+01  6e+00  1e-15
#  2: -7.7727e+00 -4.8503e+00  2e+01  2e+00  9e-16
#  3: -1.1565e+00 -3.9378e+00  1e+01  9e-01  9e-16
#  4: -3.6142e-01 -3.1771e+00  7e+00  3e-01  9e-16
#  5: -7.4474e-01 -2.9171e+00  3e+00  4e-02  9e-16
#  6: -2.5289e+00 -2.7755e+00  3e-01  7e-04  1e-15
#  7: -2.7610e+00 -2.7663e+00  5e-03  1e-05  1e-15
#  8: -2.7660e+00 -2.7661e+00  7e-05  2e-07  1e-15
#  9: -2.7661e+00 -2.7661e+00  7e-07  2e-09  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -2.1867e+02 -7.0136e+00  4e+02  5e+01  1e-15
#  1: -3.3733e+01 -6.5818e+00  6e+01  6e+00  1e-15
#  2: -5.7632e+00 -3.9099e+00  2e+01  1e+00  1e-15
#  3:  1.2609e+00 -2.7249e+00  1e+01  5e-01  1e-15
#  4:  6.8282e-01 -1.8495e+00  5e+00  2e-01  1e-15
#  5: -6.6378e-01 -1.5906e+00  1e+00  8e-03  1e-15
#  6: -1.5197e+00 -1.5553e+00  4e-02  2e-04  1e-15
#  7: -1.5537e+00 -1.5542e+00  6e-04  3e-06  1e-15
#  8: -1.5542e+00 -1.5542e+00  7e-06  3e-08  1e-15
#  9: -1.5542e+00 -1.5542e+00  7e-08  3e-10  1e-15
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -4.0979e+01  1.5536e+02  1e+03  4e+01  2e+00
#  1:  1.2944e+02 -1.0647e+01  1e+02  6e-15  3e-15
#  2:  1.7117e+01 -9.7209e+00  3e+01  3e-15  2e-15
#  3:  3.0629e+00 -8.8292e+00  1e+01  2e-15  1e-15
#  4: -3.6085e+00 -8.4344e+00  5e+00  9e-16  9e-16
#  5: -6.8375e+00 -8.2311e+00  1e+00  4e-16  9e-16
#  6: -7.9902e+00 -8.1444e+00  2e-01  9e-16  1e-15
#  7: -8.1268e+00 -8.1347e+00  8e-03  6e-16  1e-15
#  8: -8.1340e+00 -8.1342e+00  2e-04  6e-16  1e-15
#  9: -8.1342e+00 -8.1342e+00  5e-06  2e-15  1e-15
# Optimal solution found.
# Theoretical kappa: 3.7250035156206223
# Cross-validated kappa: 2.3357214690901213
#
# Error comparison:
# Theory error: 0.9035744978585789
# CV error: 0.9308111362285739
